# %%
# -*- coding: utf-8 -*-
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import make_scorer,mean_squared_error
from sklearn.model_selection import KFold,ShuffleSplit,validation_curve
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,learning_curve
import xgboost as xgb

seed = 25000

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## load data

# %%
train_raw = pd.read_csv('train.csv')
test_raw = pd.read_csv('test.csv')
store = pd.read_csv('store.csv')

# 只考虑开店营业的数据
trainset_openstore = train_raw.query('Open!=0')

# 得到每家店每日客户数的中间值，并将其定义为store popularity
store_popularity = pd.DataFrame(trainset_openstore.groupby(['Store'])['Customers'].median())
store_popularity.columns = ['store_popularity']

# 购买力 = median(Sales) / median(customers) per store
consumption = pd.DataFrame(trainset_openstore.groupby(['Store'])['Sales'].median() / trainset_openstore.groupby(['Store'])['Customers'].median())
consumption.columns = ['consumption_power']
# 将store popularity放入store信息内
store= pd.merge(store,store_popularity,left_on='Store',right_index=True)
store= pd.merge(store,consumption,left_on='Store',right_index=True)
# 将门店数据合并到训练集，测试集中
trainset = pd.merge(train_raw,store,on='Store') 
testset = pd.merge(test_raw,store,on='Store')

# %% [markdown]
# ## Data Cleaning

# %%
def clean_data(dataset):
    # 去除缺失值占比大的特征
    dataset = dataset.drop(['CompetitionOpenSinceMonth','CompetitionOpenSinceYear',
                            'Promo2SinceWeek','PromoInterval','Promo2SinceYear'],axis=1)
    
    # 将Date转换为datetime对象
    dataset['Date']=pd.to_datetime(dataset['Date'])
    
    # 创建'Month','Year'特征 
    dataset['Month'] = dataset['Date'].map(lambda x: x.month)
    dataset['Year'] = dataset['Date'].map(lambda x: x.year)

    # StateHoliday中的typo进行修正，并将当日不是节日设置为0
    dataset.loc[dataset['StateHoliday']=='0','StateHoliday']=0
    
    # 将当日是节日，则设置为1，不管是什么节日  
    dataset.loc[dataset['StateHoliday']!=0,'StateHoliday']=1
    dataset['StateHoliday']=dataset['StateHoliday'].astype('uint8')
    
    # 进行独热编码
    for x in ['StoreType','Assortment','DayOfWeek','Month']: 
        dataset = dataset.join(pd.get_dummies(dataset[x],prefix=x))

    # 对testset中缺失的月份用0填充    
    for month in range(1,13):
        head = 'Month_' + str(month)
        if head not in dataset.columns:
            dataset[head]=0
        
    if 'Customers' in dataset.columns:
        dataset = dataset.drop(['Customers'],axis=1)
    
    if 'Date' in dataset.columns:
        dataset = dataset.drop(['Date'],axis=1)
        
    dataset = dataset.drop(['StoreType','Assortment','DayOfWeek','Month'],axis=1)  # ,'Store'
    
    return dataset

# %%
trainset = clean_data(trainset) 
testset = clean_data(testset)

# %%
# 只对开店营业的数据进行学习
trainset=trainset.loc[trainset['Open']==1,:] 
trainset = trainset.drop(['Open'],axis=1)

# 去除trainset中Sales=0的异常值 54/844392
trainset = trainset.query('Sales!=0')

# %%
testset = testset.set_index('Id')
testset.sort_index(inplace=True)

# 将Sales设置为标签
Y_train = trainset.pop("Sales")

# 设置训练集
X_train = trainset

# 对标签进行对数转换
Y_train = np.log(Y_train+1)

features = list(X_train.columns)

features.remove('Store')

# %% [markdown]
# ## xgboost model

# %%
# development_set for grid cv, evaluation set for evaluation
X_dev, X_eval, Y_dev, Y_eval = train_test_split(X_train,Y_train,test_size=0.33,shuffle=True,stratify=X_train['Store'],random_state=seed)

# %%
# 设置cross-validation用的loss function
def rmspe_exp(y_true, y_predict): 
    y_true = np.exp(y_true) - 1
    y_predict = np.exp(y_predict) - 1
    w = np.zeros(y_true.shape, dtype=float)
    indice = y_true != 0
    w[indice] = 1./(y_true[indice]**2)
    score = np.sqrt(np.mean( w * (y_true - y_predict)**2 ))
    return score

rmspe_exp_error = make_scorer(rmspe_exp,greater_is_better=False)

# %%
# 设置cross-validation策略
cv =ShuffleSplit(n_splits=4,test_size=0.2,random_state=seed)

# %% [markdown]
# ### default XGBoost model

# %% [markdown]
# default params:
# ```python
# default_params = {
#     'objective':'reg:linear',
#     'max_depth':3,
#     'learning_rate':0.1,
#     'n_estimators':100,
#     'colsample_bytree':1,
#     'subsample':1
# }
# ```

# %%
default_reg=XGBRegressor(objective='reg:linear',seed=seed)

# %%
# 初始XGBoost的learning curve
train_default_sizes, train_default_scores, test_default_scores = learning_curve(
    default_reg, X_eval[features],Y_eval,train_sizes=np.linspace(0.1,1,8),cv=cv,scoring=rmspe_exp_error,
    verbose=100,shuffle=True,random_state=seed)
# Out:
# [learning_curve] Training set sizes: [ 22290  50949  79608 108268 136927 165586 194245 222905]
# [CV]  ................................................................
# [CV] ...................... , score=-0.4243509267367941, total=   0.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4189261023699607, total=   1.6s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.42693148292475586, total=   2.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.3s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.41748966176840197, total=   3.8s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.5s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.42544033071872867, total=   5.2s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   15.1s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.42462908729617577, total=   5.8s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   21.3s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4279208910160012, total=   7.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   28.9s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4187962671424783, total=   7.8s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   37.3s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.2432899288174912, total=   0.7s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   38.2s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.24300130365792502, total=   1.7s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   40.0s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.2424186131847226, total=   2.7s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   43.0s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.23950386659059178, total=   3.4s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   46.8s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.2417060565113425, total=   4.5s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   51.6s remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.2391989880178487, total=   5.5s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   57.5s remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.23896604219598713, total=   8.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  1.1min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.23982915932689744, total=   8.6s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21762000449618957, total=   0.7s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  1.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21659355629433294, total=   1.6s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  1.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21661515362411252, total=   2.5s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  1.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.2159753523732099, total=   3.6s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  1.4min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21383623404181692, total=   4.4s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  1.5min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21551663393760168, total=   5.6s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  1.6min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21649012055254022, total=   6.7s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  1.7min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.21633943453430066, total=   8.4s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  1.9min remaining:    0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-0.416506857671669, total=   0.7s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  1.9min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.42288057582234123, total=   1.6s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  1.9min remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4273593546162708, total=   2.6s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.9min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.42927096159920153, total=   3.9s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  2.0min remaining:    0.0s
# [CV]  ................................................................
# [CV] ..................... , score=-0.41264194125319037, total=   4.5s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  2.1min remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4182323907725916, total=   5.6s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  2.2min remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4164994807967535, total=   6.9s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  2.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-0.4198283390039649, total=   8.9s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  2.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  2.5min finished

# %%
# 将learning curve数据导出以便graph.ipynb绘图
learn_curve_default = pd.DataFrame({
    'train_sizes':train_default_sizes,
    'train_scores_mean':np.mean(train_default_scores,axis=1),
    'train_scores_std':np.std(train_default_scores,axis=1),
    'test_scores_mean':np.mean(test_default_scores,axis=1),
    'test_scores_std':np.std(test_default_scores,axis=1)
})
learn_curve_default=np.abs(learn_curve_default)

learn_curve_default.to_json('./json/learn_curve_default.json')

# %% [markdown]
# ### parameter tuning

# %%
# 根据domain knowledge 设置参数范围
params = {
    'n_estimators':np.arange(100,650,50),
    'max_depth':[4,5,6,7,8],
    'colsample_bytree':[0.5,0.6,0.7,0.8],
    'subsample':[0.5,0.6,0.7,0.8,],
    'learning_rate':[0.05,0.1,0.15,0.2,0.25,0.3]
}

# %%
# 使用线性的回归树
reg = XGBRegressor(objective='reg:linear',seed=seed)
# 进行随机参数选择
bst_grid = RandomizedSearchCV(estimator=reg,param_distributions=params,cv=cv,
                              scoring=rmspe_exp_error,verbose=100,n_iter=80,random_state=seed)

# %%
bst_grid.fit(X_dev[features],Y_dev)
# Out:
# Fitting 4 folds for each of 80 candidates, totalling 320 fits
# [CV] subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8, score=-0.12893101597954132, total= 4.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.7min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8, score=-0.13844258297057932, total= 4.6min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.5min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8, score=-0.14571137403114606, total= 4.5min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 14.2min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=600, max_depth=8, learning_rate=0.3, colsample_bytree=0.8, score=-0.1356598051028112, total= 4.6min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 19.0min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7
# [CV]  subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7, score=-0.19345833210574953, total=  49.4s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 19.9min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7
# [CV]  subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7, score=-0.21737210042567612, total=  48.9s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 20.7min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7
# [CV]  subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7, score=-0.20754776826089757, total=  50.3s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 21.6min remaining:    0.0s
# [CV] subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7
# [CV]  subsample=0.8, n_estimators=250, max_depth=4, learning_rate=0.05, colsample_bytree=0.7, score=-0.19477661924281148, total=  51.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 22.5min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8, score=-0.17440720822269148, total= 1.3min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 23.8min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8, score=-0.19091698832498485, total= 1.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 25.1min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8, score=-0.19073340195501554, total= 1.2min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 26.3min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=200, max_depth=6, learning_rate=0.05, colsample_bytree=0.8, score=-0.17767381998718343, total= 1.2min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 27.5min remaining:    0.0s
# [CV] subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.1593171048769255, total= 1.7min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 29.3min remaining:    0.0s
# [CV] subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.1691148052671296, total= 1.7min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 31.1min remaining:    0.0s
# [CV] subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.1751952953428758, total= 1.7min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 32.9min remaining:    0.0s
# [CV] subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=600, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.1609189918257342, total= 1.7min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 34.7min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7, score=-0.14196997607646855, total= 2.7min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 37.4min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7, score=-0.15065490360967002, total= 2.7min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 40.2min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7, score=-0.16063982064459398, total= 2.7min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 42.9min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.5, n_estimators=500, max_depth=6, learning_rate=0.15, colsample_bytree=0.7, score=-0.14581549810773572, total= 2.6min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 45.6min remaining:    0.0s
# [CV] subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.14539183105527695, total= 2.6min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 48.3min remaining:    0.0s
# [CV] subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.1527220399960784, total= 2.6min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 51.0min remaining:    0.0s
# [CV] subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.16346884548496107, total= 2.7min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 53.7min remaining:    0.0s
# [CV] subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=550, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.14857209272815244, total= 2.7min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 56.5min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8, score=-0.13106063387237846, total= 3.9min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 60.5min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8, score=-0.13973453415898962, total= 3.9min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 64.6min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8, score=-0.14945077425088749, total= 3.9min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 68.6min remaining:    0.0s
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0

# [CV] subsample=0.6, n_estimators=150, max_depth=6, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=150, max_depth=6, learning_rate=0.3, colsample_bytree=0.8, score=-0.16586505606513466, total=  54.1s
# [CV] subsample=0.6, n_estimators=150, max_depth=6, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=150, max_depth=6, learning_rate=0.3, colsample_bytree=0.8, score=-0.15308957698296777, total=  53.4s
# [CV] subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5, score=-0.1698451989119614, total=  39.2s
# [CV] subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5, score=-0.18647495657186805, total=  39.7s
# [CV] subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5, score=-0.18589662682842578, total=  39.4s
# [CV] subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=6, learning_rate=0.1, colsample_bytree=0.5, score=-0.1729020810968167, total=  39.2s
# [CV] subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7, score=-0.1445821499944704, total= 1.4min
# [CV] subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7, score=-0.1531510260488856, total= 1.4min
# [CV] subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7, score=-0.16338685295878153, total= 1.4min
# [CV] subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=200, max_depth=8, learning_rate=0.1, colsample_bytree=0.7, score=-0.14872387516381988, total= 1.4min
# [CV] subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8, score=-0.14519982235679418, total= 2.1min
# [CV] subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8, score=-0.15440806511507135, total= 2.1min
# [CV] subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8, score=-0.16342709875811953, total= 2.1min
# [CV] subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=350, max_depth=6, learning_rate=0.15, colsample_bytree=0.8, score=-0.14976413261487304, total= 2.1min
# [CV] subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8, score=-0.14158559285038913, total= 1.7min
# [CV] subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8, score=-0.15105297026903972, total= 1.8min
# [CV] subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8, score=-0.1599536482762355, total= 1.7min
# [CV] subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=250, max_depth=7, learning_rate=0.15, colsample_bytree=0.8, score=-0.1453619337408832, total= 1.7min
# [CV] subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.16740890548744555, total=  60.0s
# [CV] subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.17763925009058623, total=  60.0s
# [CV] subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.18277942757349602, total= 1.0min
# [CV] subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=350, max_depth=4, learning_rate=0.25, colsample_bytree=0.5, score=-0.16883017934823766, total=  59.8s
# [CV] subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.16333520361013748, total= 1.3min
# [CV] subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.17802398407778894, total= 1.3min
# [CV] subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.18247501819085007, total= 1.3min
# [CV] subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=200, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.1675803107991585, total= 1.3min
# [CV] subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.15516310098579453, total= 2.0min
# [CV] subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.1662368102272175, total= 2.0min
# [CV] subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.17358393828087143, total= 2.1min
# [CV] subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.15925016185744117, total= 2.0min
# [CV] subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5, score=-0.17141957191463816, total=  43.3s
# [CV] subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5, score=-0.18135853956813217, total=  43.7s
# [CV] subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5, score=-0.1849719974256385, total=  43.8s
# [CV] subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=200, max_depth=5, learning_rate=0.15, colsample_bytree=0.5, score=-0.17262426939007183, total=  43.3s
# [CV] subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6, score=-0.1690550519010421, total= 1.8min
# [CV] subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6, score=-0.18181535878895771, total= 1.9min
# [CV] subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6, score=-0.18400264893217963, total= 1.8min
# [CV] subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=600, max_depth=4, learning_rate=0.1, colsample_bytree=0.6, score=-0.17229395453483745, total= 1.8min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.12936074922672358, total= 3.7min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.13936663894626933, total= 3.6min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.14733595685056813, total= 3.6min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.1359060470483987, total= 3.7min
# [CV] subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5, score=-0.1662852787767671, total= 1.2min
# [CV] subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5, score=-0.17873127974080394, total= 1.2min
# [CV] subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5, score=-0.18179992559635644, total= 1.2min
# [CV] subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5
# [CV]  subsample=0.7, n_estimators=350, max_depth=5, learning_rate=0.1, colsample_bytree=0.5, score=-0.16914895536549993, total= 1.2min
# [CV] subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5, score=-0.15583218645020736, total= 1.1min
# [CV] subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5, score=-0.1677543853610868, total= 1.1min
# [CV] subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5, score=-0.17176453191403146, total= 1.1min
# [CV] subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=250, max_depth=6, learning_rate=0.15, colsample_bytree=0.5, score=-0.1583873527880552, total= 1.1min
# [CV] subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.13798531947353682, total= 1.6min
# [CV] subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.14700419798270106, total= 1.6min
# [CV] subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.15618357535377475, total= 1.6min
# [CV] subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=300, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.14272584944103284, total= 1.6min
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6, score=-0.1316826742661203, total= 3.1min
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6, score=-0.14145797290028903, total= 3.1min
# [CV] subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=550, max_depth=7, learning_rate=0.3, colsample_bytree=0.6, score=-0.1512966037727888, total= 3.1min
# ...
# [CV] subsample=0.6, n_estimators=100, max_depth=8, learning_rate=0.3, colsample_bytree=0.8
# [CV]  subsample=0.6, n_estimators=100, max_depth=8, learning_rate=0.3, colsample_bytree=0.8, score=-0.14483167616118586, total=  50.0s
# [CV] subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.14382613378115156, total= 1.1min
# [CV] subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.15359130972524454, total= 1.1min
# [CV] subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.1618782780650028, total= 1.1min
# [CV] subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=200, max_depth=7, learning_rate=0.2, colsample_bytree=0.6, score=-0.14787674805322873, total= 1.1min
# [CV] subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.14853356720137625, total= 3.0min
# [CV] subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.15988437690258467, total= 3.0min
# [CV] subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.1678707122166104, total= 3.0min
# [CV] subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8
# [CV]  subsample=0.8, n_estimators=450, max_depth=7, learning_rate=0.05, colsample_bytree=0.8, score=-0.15303186447556458, total= 3.0min
# [CV] subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.15479572845135628, total= 1.9min
# [CV] subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.16516388178172683, total= 1.9min
# [CV] subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.172839940492198, total= 1.9min
# [CV] subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=350, max_depth=7, learning_rate=0.05, colsample_bytree=0.6, score=-0.15920325944796054, total= 2.0min
# [CV] subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7, score=-0.19209279096286222, total=  22.0s
# [CV] subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7, score=-0.21137583015612293, total=  21.8s
# [CV] subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7, score=-0.20438945332959346, total=  21.5s
# [CV] subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=100, max_depth=4, learning_rate=0.15, colsample_bytree=0.7, score=-0.1930629248132502, total=  21.8s
# [CV] subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5, score=-0.19088414146864333, total=  48.8s
# [CV] subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5, score=-0.211175290114844, total=  48.8s
# [CV] subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5, score=-0.20384356995474862, total=  49.1s
# [CV] subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=300, max_depth=4, learning_rate=0.05, colsample_bytree=0.5, score=-0.19264839897631048, total=  48.7s
# [CV] subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6, score=-0.13953185325331469, total= 2.0min
# [CV] subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6, score=-0.14887935392688992, total= 1.9min
# [CV] subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6, score=-0.15831730453614482, total= 1.9min
# [CV] subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6
# [CV]  subsample=0.7, n_estimators=300, max_depth=8, learning_rate=0.1, colsample_bytree=0.6, score=-0.143857264152648, total= 1.9min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5, score=-0.12955820416301161, total= 3.2min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5, score=-0.13945434665954612, total= 3.2min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5, score=-0.1497575301695495, total= 3.2min
# [CV] subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.6, n_estimators=550, max_depth=8, learning_rate=0.3, colsample_bytree=0.5, score=-0.13649355311925807, total= 3.1min
# [CV] subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5, score=-0.16431949890156425, total=  55.5s
# [CV] subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5, score=-0.17335869481165267, total=  56.4s
# [CV] subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5, score=-0.17883582040771387, total=  55.1s
# [CV] subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5
# [CV]  subsample=0.8, n_estimators=350, max_depth=4, learning_rate=0.3, colsample_bytree=0.5, score=-0.1672331821695091, total=  57.1s
# [CV] subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6, score=-0.17299253306889328, total=  37.1s
# [CV] subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6, score=-0.18818866529798384, total=  37.6s
# [CV] subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6, score=-0.18768895310655073, total=  37.0s
# [CV] subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=150, max_depth=5, learning_rate=0.15, colsample_bytree=0.6, score=-0.17557399179026068, total=  36.6s
# [CV] subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7, score=-0.1299581629168129, total= 3.6min
# [CV] subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7, score=-0.1393727344494886, total= 3.6min
# [CV] subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7, score=-0.1483685376044243, total= 3.7min
# [CV] subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.7, n_estimators=600, max_depth=7, learning_rate=0.25, colsample_bytree=0.7, score=-0.13503323299476883, total= 3.6min
# [CV] subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7, score=-0.14609935213241387, total= 2.2min
# [CV] subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7, score=-0.15335532304274035, total= 2.2min
# [CV] subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7, score=-0.1617641472184813, total= 2.2min
# [CV] subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7
# [CV]  subsample=0.6, n_estimators=500, max_depth=5, learning_rate=0.25, colsample_bytree=0.7, score=-0.14996495344294716, total= 2.2min
# [CV] subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5, score=-0.19350960006280343, total=  33.3s
# [CV] subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5, score=-0.2153095587600841, total=  32.9s
# [CV] subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5, score=-0.20850366645293403, total=  32.9s
# [CV] subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5
# [CV]  subsample=0.5, n_estimators=150, max_depth=5, learning_rate=0.05, colsample_bytree=0.5, score=-0.19474530568085371, total=  32.9s
# [CV] subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.1442348653013827, total= 2.9min
# [CV] subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.15149279505173974, total= 2.8min
# [CV] subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.16221567606694343, total= 2.8min
# [CV] subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8
# [CV]  subsample=0.7, n_estimators=600, max_depth=5, learning_rate=0.2, colsample_bytree=0.8, score=-0.14736842399999753, total= 2.9min
# [CV] subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.13015668941115544, total= 2.1min
# [CV] subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.13725993038107742, total= 2.1min
# [CV] subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.14872097080447727, total= 2.1min
# [CV] subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.8, n_estimators=350, max_depth=8, learning_rate=0.25, colsample_bytree=0.6, score=-0.13614724220838315, total= 2.1min
# [CV] subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6, score=-0.15780561473316376, total= 1.2min
# [CV] subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6, score=-0.16867126223132453, total= 1.2min
# [CV] subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6, score=-0.1759051226210707, total= 1.2min
# [CV] subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6
# [CV]  subsample=0.5, n_estimators=300, max_depth=5, learning_rate=0.2, colsample_bytree=0.6, score=-0.16133782054444967, total= 1.2min
# [CV] subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6, score=-0.15401142598781492, total=  34.3s
# [CV] subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6, score=-0.16556439715682447, total=  34.3s
# [CV] subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6, score=-0.16955103501678528, total=  34.6s
# [CV] subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6
# [CV]  subsample=0.6, n_estimators=100, max_depth=7, learning_rate=0.25, colsample_bytree=0.6, score=-0.15783330883861688, total=  35.0s
# [Parallel(n_jobs=1)]: Done 320 out of 320 | elapsed: 569.2min finished
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=4, random_state=25000, test_size=0.2, train_size=None),
#           error_score='raise',
#           estimator=XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=1, gamma=0,
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=25000, silent=True, subsample=1),
#           fit_params=None, iid=True, n_iter=80, n_jobs=1,
#           param_distributions={'n_estimators': array([100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600]), 'max_depth': [4, 5, 6, 7, 8], 'colsample_bytree': [0.5, 0.6, 0.7, 0.8], 'subsample': [0.5, 0.6, 0.7, 0.8], 'learning_rate': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3]},
#           pre_dispatch='2*n_jobs', random_state=25000, refit=True,
#           return_train_score=True,
#           scoring=make_scorer(rmspe_exp, greater_is_better=False),
#           verbose=100)

# %%
bst_grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.25,
#  'max_depth': 8,
#  'n_estimators': 550,
#  'subsample': 0.8}

# %%
# 将cv过程结果写入json文件以便graph.ipynb绘图
cv_result = pd.DataFrame(bst_grid.cv_results_) #
cv_result.index=cv_result.index+1

cv_result.to_json('./json/cvresults_random.json')

# %% [markdown]
# ## predict and test --- optimized model

# %%
def rmspe_xg(y_predict,y_true): 
    y_true = np.exp(y_true) - 1
    y_predict = np.exp(y_predict) - 1
    w = np.zeros(y_true.shape, dtype=float)
    indice = y_true != 0
    w[indice] = 1./(y_true[indice]**2)
    score = np.sqrt(np.mean( w * (y_true - y_predict)**2 ))
    return 'rmspe_xg', score

# %%
# 最佳参数组合
param_origin_xgb = {
    'objective':'reg:linear', 
    'max_depth':8,
    'eta':0.25,  # 同learning_rate 
    'colsample_bytree':0.8,
    'subsample':0.8,
    'seed': seed
}
n_rounds = 550  # 同n_estimators
# dtrain = xgb.DMatrix(X_train,Y_train)  # 训练模型

# %%
dtrain = xgb.DMatrix(X_train[features],Y_train) 
dtest = xgb.DMatrix(testset[features])

# %%
origin_reg = xgb.train(param_origin_xgb,dtrain,n_rounds,feval=rmspe_xg) # 预测testset

# %%
# 预测
def output_csv(estimator, name,benchmark=False):
    predict_name = 'prdict' + name
    output_name = 'sample_submission_' + name
    if benchmark:
        testset[predict_name] = estimator.predict(X_test_linear)
    else:
        testset[predict_name] = estimator.predict(dtest)
        
    testset[predict_name] = np.exp(testset[predict_name])-1

    ind = testset[predict_name]<0
    testset.loc[ind,predict_name]=0

    # 对关店的数据直接预测Sales=0
    Open_0_indice=testset['Open']==0
    testset.loc[Open_0_indice,predict_name]=0

    test_submission = pd.DataFrame({'Id':list(testset.index),
    "Sales":testset[predict_name]})

    test_submission.to_csv(r'./score_sheet/{}.csv'.format(output_name),index=False)
    return None

# %%
output_csv(origin_reg,'optimized')

# %%
# 将特征重要性信息导入json文件，以便后续graph.ipynb绘图
feature_list, gain_list = zip(*[(key, value) for (key, value) in origin_reg.get_score().items()])
feature_importance = pd.DataFrame({'Feature':feature_list,'Gain':gain_list})
feature_importance.to_json(r'./json/feature_importance.json')

# %% [markdown]
# ## Linear regression(benchmark)

# %%
features_linear = features.copy()

# 消除多重共线问题
for x in ['StoreType_d','Assortment_c','DayOfWeek_7','Month_12']:
    features_linear.remove(x)

# %%
# 缺失值用均值替代
X_train_linear = X_train[features_linear].apply(lambda x: x.fillna(x.mean()),axis=0)
X_test_linear = testset[features_linear]
X_test_linear= X_test_linear.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
# 线性回归
linear_reg = LinearRegression()

linear_reg.fit(X_train_linear,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
output_csv(linear_reg,'linear',benchmark=True)
